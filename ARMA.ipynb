# %% [markdown]
# # ARMA model

# %% [markdown]
# #### Import libraries

# %%
#from libraries import *
# %run libraries.py

# %% [markdown]
# Load previously preprocessed time series

# %%
#ts = load_data(path='processed_data/') # does not work for some reason
ts = pd.read_csv('processed_data/BTCUSDT_1h.csv')
ts.set_index('timestamp', inplace=True)
ts.index = pd.to_datetime(ts.index)
ts.head()
# Out:
#                close
# timestamp
# 2020-07-14 -0.004190
# 2020-07-15  0.004304
# 2020-07-16 -0.008426
# 2020-07-17  0.005721
# 2020-07-18  0.003534

# %%
#plot_acf(ts, lags=len(ts)-1);

# %%
#plot_pacf(ts, lags=len(ts)-1);

# %%
plot_autocorr(ts)

# %%
# Difference the time series
#data_diff = ts.diff(periods=1).dropna()
#data_diff
#check_stationarity(ts)
# Out:
#                close
# timestamp
# 2020-07-15  0.008494
# 2020-07-16 -0.012731
# 2020-07-17  0.014148
# 2020-07-18 -0.002187
# 2020-07-19 -0.004934
# ...              ...
# 2021-11-20  0.040238
# 2021-11-21 -0.015686
# 2021-11-22 -0.063182
# 2021-11-23  0.044255
# 2021-11-24  0.038466
#
# [498 rows x 1 columns]

# %%
ts_original = load_data()

# %%
arma = ARMA(ts_original, order=(1,0))
res = arma.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  close   No. Observations:                  500
# Model:                     ARMA(1, 0)   Log Likelihood               -4446.668
# Method:                       css-mle   S.D. of innovations           1752.842
# Date:                Sun, 28 Nov 2021   AIC                           8899.337
# Time:                        18:47:26   BIC                           8911.980
# Sample:                    07-13-2020   HQIC                          8904.298
#                          - 11-24-2021
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         4.97e+04        nan        nan        nan         nan         nan
# ar.L1.close     0.9977        nan        nan        nan         nan         nan
# ...

# %%
arma = ARMA(ts_original, order=(1,1))
res = arma.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  close   No. Observations:                  500
# Model:                     ARMA(1, 1)   Log Likelihood               -4444.723
# Method:                       css-mle   S.D. of innovations           1746.357
# Date:                Sun, 28 Nov 2021   AIC                           8897.445
# Time:                        18:47:31   BIC                           8914.304
# Sample:                    07-13-2020   HQIC                          8904.061
#                          - 11-24-2021
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.519e+04    3.6e+04      1.255      0.210   -2.54e+04    1.16e+05
# ar.L1.close     0.9977      0.005    220.001      0.000       0.989       1.007
# ...

# %%
arma = ARMA(ts_original, order=(2,1))
res = arma.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  close   No. Observations:                  500
# Model:                     ARMA(2, 1)   Log Likelihood               -4444.476
# Method:                       css-mle   S.D. of innovations           1746.060
# Date:                Sun, 28 Nov 2021   AIC                           8898.951
# Time:                        18:47:35   BIC                           8920.024
# Sample:                    07-13-2020   HQIC                          8907.220
#                          - 11-24-2021
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         3.44e+04   1.46e+04      2.351      0.019    5718.775    6.31e+04
# ar.L1.close     0.2882      0.194      1.488      0.137      -0.091       0.668
# ...

# %%
arma = ARMA(ts_original, order=(2,2))
res = arma.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                  close   No. Observations:                  500
# Model:                     ARMA(2, 2)   Log Likelihood               -4444.305
# Method:                       css-mle   S.D. of innovations           1745.419
# Date:                Sun, 28 Nov 2021   AIC                           8900.611
# Time:                        18:47:39   BIC                           8925.898
# Sample:                    07-13-2020   HQIC                          8910.534
#                          - 11-24-2021
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         3.44e+04   1.55e+04      2.216      0.027    3971.484    6.48e+04
# ar.L1.close     1.1339      0.499      2.271      0.023       0.155       2.113
# ...

# %%
def model(ts, order=(0,0,0)):
    
    # split into train and test sets
    X = ts.close
    size = int(len(X) * 0.66)
    train, test = X[0:size], X[size:len(X)]
    history = [x for x in train]
    predictions = list()

    # walk-forward validation
    for t in range(len(test)):
        model = ARMA(history, order=order)
        model_fit = model.fit()
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
        print('predicted=%f, expected=%f' % (yhat, obs))
        
    # evaluate forecasts
    rmse = sqrt(mean_squared_error(test, predictions))
    print('Test RMSE: %.3f' % rmse)

    return test, predictions

# %%
test, predictions = model(ts_original, (3,3))
#data_diff = ts_original.diff(periods=1).dropna()
#test, predictions = model(data_diff, (3,3,0))
# Out:
# predicted=33998.383867, expected=30969.000000
# predicted=30669.659940, expected=32390.000000
# predicted=32487.001749, expected=35750.000000
# predicted=35850.387679, expected=35900.000000
# predicted=34901.179960, expected=34585.900000
# predicted=35205.197053, expected=34739.060000
# predicted=34803.235010, expected=38720.000000
# predicted=37813.164807, expected=39500.000000
# predicted=39971.260951, expected=38105.000000
# predicted=37478.987840, expected=37334.760000
# predicted=37585.920164, expected=35100.000000
# predicted=35696.114140, expected=34704.080000
# predicted=34000.748106, expected=33312.000000
# predicted=34151.916616, expected=31250.510000
# predicted=31141.592445, expected=28780.010000
# predicted=28708.329599, expected=31711.500000
# predicted=32357.080793, expected=32300.000000
# predicted=31468.789331, expected=31250.000000
# predicted=31301.148689, expected=30120.000000
# predicted=30888.350940, expected=31960.000000
# ...

# %%
plot_ts([[test, 'Actual'], [predictions, 'Predictions']], 'Forecasts against actual outcomes', 'Days')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/learn-env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.conda/envs/learn-env/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
data_diff = ts_original.diff(periods=1).dropna()
test_diff, predictions_diff = model(data_diff, (1,1,0))
# Out:
# predicted=323.855822, expected=-2231.000000
# predicted=358.964960, expected=1421.000000
# predicted=-52.565145, expected=3360.000000
# predicted=-319.434722, expected=150.000000
# predicted=-16.193598, expected=-1314.100000
# predicted=208.651119, expected=153.160000
# predicted=101.821629, expected=3980.940000
# predicted=-354.961742, expected=780.000000
# predicted=-104.849544, expected=-1395.000000
# predicted=192.256673, expected=-770.240000
# predicted=209.327047, expected=-2234.760000
# predicted=369.270502, expected=-395.920000
# predicted=215.943294, expected=-1392.080000
# predicted=264.572947, expected=-2061.490000
# predicted=332.791427, expected=-2470.500000
# predicted=360.156100, expected=2931.490000
# predicted=-138.566827, expected=588.500000
# predicted=-42.900827, expected=-1050.000000
# predicted=146.189802, expected=-1130.000000
# predicted=206.277402, expected=1840.000000
# predicted=-73.749477, expected=1895.000000
# predicted=-156.334322, expected=351.000000
# ...

# %%
plot_ts([[test_diff, 'Actual'], [predictions_diff, 'Predictions']], 'Forecasts against actual outcomes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/learn-env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.conda/envs/learn-env/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
plot_ts([[test_diff, 'Actual'], [predictions_diff, 'Predictions']], 'Forecasts against actual outcomes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-400b12509762> in <module>
# ----> 1 plot_ts([[test_diff, 'Actual'], [predictions_diff, 'Predictions']], 'Forecasts against actual outcomes')
#
# NameError: name 'test_diff' is not defined
